# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# !py -mpip install tensorflow tensorflow-gpu opencv-python mediapipe sklearn matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (2.13.0)
# Collecting tensorflow-gpu
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
# Requirement already satisfied: opencv-python in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (4.8.0.76)
# Requirement already satisfied: mediapipe in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (0.10.3)
# Requirement already satisfied: sklearn in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (0.0.post7)
# Requirement already satisfied: matplotlib in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (3.8.0)
# Requirement already satisfied: tensorflow-intel==2.13.0; platform_system == "Windows" in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: python_version>"3.7" in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-gpu) (0.0.2)
# Requirement already satisfied: numpy>=1.19.3; python_version >= "3.9" in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from opencv-python) (1.25.1)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: absl-py in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (4.8.0.76)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: cycler>=0.10 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (6.0.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.41.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (2.3.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (2.13.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (4.5.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (16.0.6)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (2.13.0)
# Requirement already satisfied: setuptools in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (49.2.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1; platform_machine != "arm64" or platform_system != "Darwin" in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (0.31.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (1.15.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (0.4.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (2.13.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (1.57.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (3.9.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib) (3.16.2)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (2.22.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (2.31.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (2.3.7)
# Requirement already satisfied: wheel>=0.26 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (0.41.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (0.7.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (3.4.4)
# Requirement already satisfied: pycparser in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (1.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (1.26.16)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (0.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (2.1.3)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (6.8.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (3.2.2)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\caioc\appdata\local\programs\python\python39\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0; platform_system == "Windows"->tensorflow) (0.5.0)
# Building wheels for collected packages: tensorflow-gpu
#   Building wheel for tensorflow-gpu (setup.py): started
#   Building wheel for tensorflow-gpu (setup.py): finished with status 'error'
#   Running setup.py clean for tensorflow-gpu
# Failed to build tensorflow-gpu
# Installing collected packages: tensorflow-gpu
#     Running setup.py install for tensorflow-gpu: started
#     Running setup.py install for tensorflow-gpu: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\caioc\AppData\Local\Programs\Python\Python39\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\caioc\\AppData\\Local\\Temp\\pip-install-r7v9yjfj\\tensorflow-gpu\\setup.py'"'"'; __file__='"'"'C:\\Users\\caioc\\AppData\\Local\\Temp\\pip-install-r7v9yjfj\\tensorflow-gpu\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\caioc\AppData\Local\Temp\pip-wheel-it04h8gw'
#        cwd: C:\Users\caioc\AppData\Local\Temp\pip-install-r7v9yjfj\tensorflow-gpu\
#   Complete output (17 lines):
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\caioc\AppData\Local\Temp\pip-install-r7v9yjfj\tensorflow-gpu\setup.py", line 37, in <module>
#       raise Exception(TF_REMOVAL_WARNING)
#   Exception:
#
#   =========================================================
#   The "tensorflow-gpu" package has been removed!
#
#   Please install "tensorflow" instead.
#
#   Other than the name, the two packages have been identical
#   since TensorFlow 2.1, or roughly since Sep 2019. For more
#   information, see: pypi.org/project/tensorflow-gpu
#   =========================================================
#
#
#   ----------------------------------------
#   ERROR: Failed building wheel for tensorflow-gpu
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\caioc\AppData\Local\Programs\Python\Python39\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\caioc\\AppData\\Local\\Temp\\pip-install-r7v9yjfj\\tensorflow-gpu\\setup.py'"'"'; __file__='"'"'C:\\Users\\caioc\\AppData\\Local\\Temp\\pip-install-r7v9yjfj\\tensorflow-gpu\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\caioc\AppData\Local\Temp\pip-record-zmi2_oov\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\caioc\AppData\Local\Programs\Python\Python39\Include\tensorflow-gpu'
#          cwd: C:\Users\caioc\AppData\Local\Temp\pip-install-r7v9yjfj\tensorflow-gpu\
#     Complete output (17 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\caioc\AppData\Local\Temp\pip-install-r7v9yjfj\tensorflow-gpu\setup.py", line 37, in <module>
#         raise Exception(TF_REMOVAL_WARNING)
#     Exception:
#
#     =========================================================
#     The "tensorflow-gpu" package has been removed!
#
#     Please install "tensorflow" instead.
#
#     Other than the name, the two packages have been identical
#     since TensorFlow 2.1, or roughly since Sep 2019. For more
#     information, see: pypi.org/project/tensorflow-gpu
#     =========================================================
#
#
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\caioc\AppData\Local\Programs\Python\Python39\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\caioc\\AppData\\Local\\Temp\\pip-install-r7v9yjfj\\tensorflow-gpu\\setup.py'"'"'; __file__='"'"'C:\\Users\\caioc\\AppData\\Local\\Temp\\pip-install-r7v9yjfj\\tensorflow-gpu\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\caioc\AppData\Local\Temp\pip-record-zmi2_oov\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\caioc\AppData\Local\Programs\Python\Python39\Include\tensorflow-gpu' Check the logs for full command output.
# WARNING: You are using pip version 20.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Users\caioc\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 10
#       7 ret, frame = cap.read()
#       9 # Make detections
# ---> 10 image, results = mediapipe_detection(frame, holistic)
#      11 print(results)
#      13 # Draw landmarks
#
# Cell In[4], line 4, in mediapipe_detection(image, model)
#       2 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
#       3 image.flags.writeable = False                  # Image is no longer writeable
# ----> 4 results = model.process(image)                 # Make prediction
#       5 image.flags.writeable = True                   # Image is now writeable
#       6 image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mediapipe\python\solutions\holistic.py:160, in Holistic.process(self, image)
#     136 def process(self, image: np.ndarray) -> NamedTuple:
#     137   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     138
#     139   Args:
#    (...)
#     157          "enable_segmentation" is set to true.
#     158   """
# --> 160   results = super().process(input_data={'image': image})
#     161   if results.pose_landmarks:  # pytype: disable=attribute-error
#     162     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mediapipe\python\solution_base.py:365, in SolutionBase.process(self, input_data)
#     359   else:
#     360     self._graph.add_packet_to_input_stream(
#     361         stream=stream_name,
#     362         packet=self._make_packet(input_stream_type,
#     363                                  data).at(self._simulated_timestamp))
# --> 365 self._graph.wait_until_idle()
#     366 # Create a NamedTuple object where the field names are mapping to the graph
#     367 # output stream names.
#     368 solution_outputs = collections.namedtuple(
#     369     'SolutionOutputs', self._output_stream_type_info.keys())
#
# KeyboardInterrupt:

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 len(results.left_hand_landmarks.landmark)
#
# AttributeError: 'NoneType' object has no attribute 'landmark'

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.45083842,  0.41975704, -1.13431144, ...,  0.        ,
#         0.        ,  0.        ])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.45083842,  0.41975704, -1.13431144, ...,  0.        ,
#         0.        ,  0.        ])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['oi', 'obrigado', 'euteamo'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 30

# %%
for action in actions: 
    # Filter out non-numeric directory names
    dirs = [d for d in os.listdir(os.path.join(DATA_PATH, action)) if d.isdigit()]
    if dirs:  # Check if there are any directories after filtering
        dirmax = np.max(np.array(dirs).astype(int))
    else:
        dirmax = 0  # If no directories, start with 0

    for sequence in range(1, no_sequences+1):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(dirmax+sequence)))
        except FileExistsError:
            pass  # If the directory already exists, just pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(start_folder, start_folder+no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 17
#      14 ret, frame = cap.read()
#      16 # Make detections
# ---> 17 image, results = mediapipe_detection(frame, holistic)
#      19 # Draw landmarks
#      20 draw_styled_landmarks(image, results)
#
# Cell In[4], line 4, in mediapipe_detection(image, model)
#       2 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
#       3 image.flags.writeable = False                  # Image is no longer writeable
# ----> 4 results = model.process(image)                 # Make prediction
#       5 image.flags.writeable = True                   # Image is now writeable
#       6 image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mediapipe\python\solutions\holistic.py:160, in Holistic.process(self, image)
#     136 def process(self, image: np.ndarray) -> NamedTuple:
#     137   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     138
#     139   Args:
#    (...)
#     157          "enable_segmentation" is set to true.
#     158   """
# --> 160   results = super().process(input_data={'image': image})
#     161   if results.pose_landmarks:  # pytype: disable=attribute-error
#     162     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mediapipe\python\solution_base.py:365, in SolutionBase.process(self, input_data)
#     359   else:
#     360     self._graph.add_packet_to_input_stream(
#     361         stream=stream_name,
#     362         packet=self._make_packet(input_stream_type,
#     363                                  data).at(self._simulated_timestamp))
# --> 365 self._graph.wait_until_idle()
#     366 # Create a NamedTuple object where the field names are mapping to the graph
#     367 # output stream names.
#     368 solution_outputs = collections.namedtuple(
#     369     'SolutionOutputs', self._output_stream_type_info.keys())
#
# KeyboardInterrupt:

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'iloveyou': 2}

# %%
sequences, labels = [], []
for action in actions:
    # Filter out non-numeric directory names
    dir_names = [d for d in os.listdir(os.path.join(DATA_PATH, action)) if d.isdigit()]
    for sequence in np.array(dir_names).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (93, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (93,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (93, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (5, 3)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 3/3 [==============================] - 4s 94ms/step - loss: 1.2474 - categorical_accuracy: 0.3409
# Epoch 2/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.5459 - categorical_accuracy: 0.2955
# Epoch 3/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.1801 - categorical_accuracy: 0.2727
# Epoch 4/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.0993 - categorical_accuracy: 0.4432
# Epoch 5/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.2586 - categorical_accuracy: 0.4432
# Epoch 6/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.1811 - categorical_accuracy: 0.3182
# Epoch 7/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.2129 - categorical_accuracy: 0.3068
# Epoch 8/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.1105 - categorical_accuracy: 0.2841
# Epoch 9/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.0990 - categorical_accuracy: 0.3295
# Epoch 10/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0946 - categorical_accuracy: 0.3295
# Epoch 11/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0917 - categorical_accuracy: 0.3295
# Epoch 12/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0893 - categorical_accuracy: 0.3295
# Epoch 13/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 1.0718 - categorical_accuracy: 0.3409
# Epoch 14/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 1.0062 - categorical_accuracy: 0.3295
# Epoch 15/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0595 - categorical_accuracy: 0.5114
# Epoch 16/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 3.2615 - categorical_accuracy: 0.4091
# Epoch 17/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.1062 - categorical_accuracy: 0.4432
# Epoch 18/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.1002 - categorical_accuracy: 0.3182
# Epoch 19/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 1.0993 - categorical_accuracy: 0.3295
# Epoch 20/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0992 - categorical_accuracy: 0.3295
# Epoch 21/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0992 - categorical_accuracy: 0.3295
# Epoch 22/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0990 - categorical_accuracy: 0.3295
# Epoch 23/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0989 - categorical_accuracy: 0.3295
# Epoch 24/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0991 - categorical_accuracy: 0.3295
# Epoch 25/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0990 - categorical_accuracy: 0.3068
# Epoch 26/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0987 - categorical_accuracy: 0.3864
# Epoch 27/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0986 - categorical_accuracy: 0.3409
# Epoch 28/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 29/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0983 - categorical_accuracy: 0.3409
# Epoch 30/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0988 - categorical_accuracy: 0.3409
# Epoch 31/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0982 - categorical_accuracy: 0.3409
# Epoch 32/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0984 - categorical_accuracy: 0.3409
# Epoch 33/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0983 - categorical_accuracy: 0.3409
# Epoch 34/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0980 - categorical_accuracy: 0.3409
# Epoch 35/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0979 - categorical_accuracy: 0.3409
# Epoch 36/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0981 - categorical_accuracy: 0.3409
# Epoch 37/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0980 - categorical_accuracy: 0.3409
# Epoch 38/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.0978 - categorical_accuracy: 0.3409
# Epoch 39/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0981 - categorical_accuracy: 0.3409
# Epoch 40/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 1.0982 - categorical_accuracy: 0.3409
# Epoch 41/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0976 - categorical_accuracy: 0.3409
# Epoch 42/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0975 - categorical_accuracy: 0.3409
# Epoch 43/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0972 - categorical_accuracy: 0.3409
# Epoch 44/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0970 - categorical_accuracy: 0.3409
# Epoch 45/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0970 - categorical_accuracy: 0.3409
# Epoch 46/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0968 - categorical_accuracy: 0.3409
# Epoch 47/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0964 - categorical_accuracy: 0.3409
# Epoch 48/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0960 - categorical_accuracy: 0.3409
# Epoch 49/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.0956 - categorical_accuracy: 0.3409
# Epoch 50/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0966 - categorical_accuracy: 0.3409
# Epoch 51/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0927 - categorical_accuracy: 0.3409
# Epoch 52/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0911 - categorical_accuracy: 0.3409
# Epoch 53/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0855 - categorical_accuracy: 0.3409
# Epoch 54/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.1479 - categorical_accuracy: 0.2841
# Epoch 55/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 1.1168 - categorical_accuracy: 0.2955
# Epoch 56/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.1221 - categorical_accuracy: 0.2955
# Epoch 57/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0913 - categorical_accuracy: 0.3068
# Epoch 58/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.7583 - categorical_accuracy: 0.2841
# Epoch 59/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.1010 - categorical_accuracy: 0.3295
# Epoch 60/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0993 - categorical_accuracy: 0.3295
# Epoch 61/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0998 - categorical_accuracy: 0.3295
# Epoch 62/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.0996 - categorical_accuracy: 0.3295
# Epoch 63/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0997 - categorical_accuracy: 0.3295
# Epoch 64/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0996 - categorical_accuracy: 0.3295
# Epoch 65/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0995 - categorical_accuracy: 0.3295
# Epoch 66/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0995 - categorical_accuracy: 0.3295
# Epoch 67/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.0995 - categorical_accuracy: 0.3295
# Epoch 68/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0995 - categorical_accuracy: 0.3295
# Epoch 69/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0995 - categorical_accuracy: 0.3295
# Epoch 70/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0994 - categorical_accuracy: 0.3295
# Epoch 71/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 1.0993 - categorical_accuracy: 0.3295
# Epoch 72/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0992 - categorical_accuracy: 0.3295
# Epoch 73/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0995 - categorical_accuracy: 0.1818
# Epoch 74/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0992 - categorical_accuracy: 0.2955
# Epoch 75/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0991 - categorical_accuracy: 0.3295
# Epoch 76/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.0991 - categorical_accuracy: 0.3295
# Epoch 77/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.0991 - categorical_accuracy: 0.2614
# Epoch 78/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0990 - categorical_accuracy: 0.2386
# Epoch 79/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0990 - categorical_accuracy: 0.3295
# Epoch 80/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0989 - categorical_accuracy: 0.3295
# Epoch 81/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 1.0989 - categorical_accuracy: 0.3295
# Epoch 82/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0989 - categorical_accuracy: 0.3295
# Epoch 83/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0988 - categorical_accuracy: 0.3295
# Epoch 84/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0988 - categorical_accuracy: 0.3295
# Epoch 85/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0988 - categorical_accuracy: 0.3295
# Epoch 86/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0988 - categorical_accuracy: 0.3295
# Epoch 87/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0987 - categorical_accuracy: 0.3295
# Epoch 88/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0987 - categorical_accuracy: 0.3295
# Epoch 89/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0986 - categorical_accuracy: 0.3295
# Epoch 90/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0987 - categorical_accuracy: 0.3295
# Epoch 91/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 1.0986 - categorical_accuracy: 0.3295
# Epoch 92/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0986 - categorical_accuracy: 0.3295
# Epoch 93/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0986 - categorical_accuracy: 0.3295
# Epoch 94/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0985 - categorical_accuracy: 0.3295
# Epoch 95/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0985 - categorical_accuracy: 0.3295
# Epoch 96/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 97/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 98/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 99/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0984 - categorical_accuracy: 0.3409
# Epoch 100/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0984 - categorical_accuracy: 0.3409
# Epoch 101/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 1.0983 - categorical_accuracy: 0.3409
# Epoch 102/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0983 - categorical_accuracy: 0.3409
# Epoch 103/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0983 - categorical_accuracy: 0.3409
# Epoch 104/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0981 - categorical_accuracy: 0.3409
# Epoch 105/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0982 - categorical_accuracy: 0.3409
# Epoch 106/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0979 - categorical_accuracy: 0.3409
# Epoch 107/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0978 - categorical_accuracy: 0.3409
# Epoch 108/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0977 - categorical_accuracy: 0.3409
# Epoch 109/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0975 - categorical_accuracy: 0.3409
# Epoch 110/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0974 - categorical_accuracy: 0.3409
# Epoch 111/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 1.0970 - categorical_accuracy: 0.3409
# Epoch 112/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0968 - categorical_accuracy: 0.3409
# Epoch 113/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0963 - categorical_accuracy: 0.3409
# Epoch 114/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0956 - categorical_accuracy: 0.3409
# Epoch 115/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0944 - categorical_accuracy: 0.3409
# Epoch 116/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0944 - categorical_accuracy: 0.3295
# Epoch 117/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.0919 - categorical_accuracy: 0.2955
# Epoch 118/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0885 - categorical_accuracy: 0.3750
# Epoch 119/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0840 - categorical_accuracy: 0.5227
# Epoch 120/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0781 - categorical_accuracy: 0.5455
# Epoch 121/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 1.0753 - categorical_accuracy: 0.4432
# Epoch 122/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0587 - categorical_accuracy: 0.5341
# Epoch 123/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0074 - categorical_accuracy: 0.6136
# Epoch 124/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0833 - categorical_accuracy: 0.3977
# Epoch 125/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0831 - categorical_accuracy: 0.3295
# Epoch 126/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0773 - categorical_accuracy: 0.3295
# Epoch 127/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0367 - categorical_accuracy: 0.3295
# Epoch 128/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.2738 - categorical_accuracy: 0.4205
# Epoch 129/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0869 - categorical_accuracy: 0.3636
# Epoch 130/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.1033 - categorical_accuracy: 0.3409
# Epoch 131/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.1032 - categorical_accuracy: 0.3409
# Epoch 132/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.1027 - categorical_accuracy: 0.3409
# Epoch 133/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.1017 - categorical_accuracy: 0.3409
# Epoch 134/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.1008 - categorical_accuracy: 0.3409
# Epoch 135/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.1010 - categorical_accuracy: 0.3409
# Epoch 136/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.1003 - categorical_accuracy: 0.3409
# Epoch 137/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0998 - categorical_accuracy: 0.3409
# Epoch 138/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0991 - categorical_accuracy: 0.3409
# Epoch 139/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0992 - categorical_accuracy: 0.3409
# Epoch 140/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0991 - categorical_accuracy: 0.3409
# Epoch 141/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0991 - categorical_accuracy: 0.3409
# Epoch 142/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0989 - categorical_accuracy: 0.3409
# Epoch 143/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0989 - categorical_accuracy: 0.3409
# Epoch 144/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0988 - categorical_accuracy: 0.3409
# Epoch 145/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0988 - categorical_accuracy: 0.3409
# Epoch 146/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0988 - categorical_accuracy: 0.3409
# Epoch 147/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0988 - categorical_accuracy: 0.3409
# Epoch 148/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0988 - categorical_accuracy: 0.3409
# Epoch 149/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0988 - categorical_accuracy: 0.3409
# Epoch 150/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.0988 - categorical_accuracy: 0.3409
# Epoch 151/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0988 - categorical_accuracy: 0.3409
# Epoch 152/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 153/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 154/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 155/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0988 - categorical_accuracy: 0.3409
# Epoch 156/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 157/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 158/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0988 - categorical_accuracy: 0.3409
# Epoch 159/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 160/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 161/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0988 - categorical_accuracy: 0.3409
# Epoch 162/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 163/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0989 - categorical_accuracy: 0.3409
# Epoch 164/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 165/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0986 - categorical_accuracy: 0.3409
# Epoch 166/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0986 - categorical_accuracy: 0.3409
# Epoch 167/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 168/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 169/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 170/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 171/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 172/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0986 - categorical_accuracy: 0.3409
# Epoch 173/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0988 - categorical_accuracy: 0.3409
# Epoch 174/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0986 - categorical_accuracy: 0.3409
# Epoch 175/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 176/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 177/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0989 - categorical_accuracy: 0.3409
# Epoch 178/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0986 - categorical_accuracy: 0.3409
# Epoch 179/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 180/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 181/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0986 - categorical_accuracy: 0.3409
# Epoch 182/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0986 - categorical_accuracy: 0.3409
# Epoch 183/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0986 - categorical_accuracy: 0.3409
# Epoch 184/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0986 - categorical_accuracy: 0.3409
# Epoch 185/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0986 - categorical_accuracy: 0.3409
# Epoch 186/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 187/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0986 - categorical_accuracy: 0.3409
# Epoch 188/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0986 - categorical_accuracy: 0.3409
# Epoch 189/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 190/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.0987 - categorical_accuracy: 0.3409
# Epoch 191/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 192/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 193/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0986 - categorical_accuracy: 0.3409
# Epoch 194/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 195/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 196/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 197/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0986 - categorical_accuracy: 0.3409
# Epoch 198/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 199/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 200/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 201/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 202/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0984 - categorical_accuracy: 0.3409
# Epoch 203/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0984 - categorical_accuracy: 0.3409
# Epoch 204/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0984 - categorical_accuracy: 0.3409
# Epoch 205/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0984 - categorical_accuracy: 0.3409
# Epoch 206/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0984 - categorical_accuracy: 0.3409
# Epoch 207/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0983 - categorical_accuracy: 0.3409
# Epoch 208/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 209/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0983 - categorical_accuracy: 0.3409
# Epoch 210/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0984 - categorical_accuracy: 0.3409
# Epoch 211/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0983 - categorical_accuracy: 0.3409
# Epoch 212/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0983 - categorical_accuracy: 0.3409
# Epoch 213/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0985 - categorical_accuracy: 0.3409
# Epoch 214/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0981 - categorical_accuracy: 0.3409
# Epoch 215/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0982 - categorical_accuracy: 0.3409
# Epoch 216/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0981 - categorical_accuracy: 0.3409
# Epoch 217/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0981 - categorical_accuracy: 0.3409
# Epoch 218/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.0980 - categorical_accuracy: 0.3409
# Epoch 219/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0979 - categorical_accuracy: 0.3409
# Epoch 220/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0979 - categorical_accuracy: 0.3409
# Epoch 221/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0980 - categorical_accuracy: 0.3409
# Epoch 222/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0978 - categorical_accuracy: 0.3409
# Epoch 223/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0975 - categorical_accuracy: 0.3409
# Epoch 224/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0975 - categorical_accuracy: 0.3409
# Epoch 225/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0973 - categorical_accuracy: 0.3409
# Epoch 226/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0975 - categorical_accuracy: 0.3409
# Epoch 227/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 1.0972 - categorical_accuracy: 0.3409
# Epoch 228/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0966 - categorical_accuracy: 0.3409
# Epoch 229/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0965 - categorical_accuracy: 0.3409
# Epoch 230/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0959 - categorical_accuracy: 0.3409
# Epoch 231/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0955 - categorical_accuracy: 0.3409
# Epoch 232/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0938 - categorical_accuracy: 0.3409
# Epoch 233/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0930 - categorical_accuracy: 0.3409
# Epoch 234/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0884 - categorical_accuracy: 0.3409
# Epoch 235/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0832 - categorical_accuracy: 0.3409
# Epoch 236/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0795 - categorical_accuracy: 0.3409
# Epoch 237/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0786 - categorical_accuracy: 0.3409
# Epoch 238/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.1484 - categorical_accuracy: 0.3409
# Epoch 239/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0978 - categorical_accuracy: 0.3295
# Epoch 240/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.0980 - categorical_accuracy: 0.3295
# Epoch 241/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.1002 - categorical_accuracy: 0.3295
# Epoch 242/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.1007 - categorical_accuracy: 0.3295
# Epoch 243/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.1010 - categorical_accuracy: 0.3295
# Epoch 244/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.1011 - categorical_accuracy: 0.3295
# Epoch 245/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.1007 - categorical_accuracy: 0.3295
# Epoch 246/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 1.1002 - categorical_accuracy: 0.3295
# Epoch 247/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0997 - categorical_accuracy: 0.3295
# Epoch 248/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0997 - categorical_accuracy: 0.3295
# Epoch 249/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0991 - categorical_accuracy: 0.3295
# Epoch 250/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0988 - categorical_accuracy: 0.3295
# Epoch 251/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0986 - categorical_accuracy: 0.3295
# Epoch 252/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.0986 - categorical_accuracy: 0.3295
# Epoch 253/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0984 - categorical_accuracy: 0.3295
# Epoch 254/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0985 - categorical_accuracy: 0.3295
# Epoch 255/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 1.0985 - categorical_accuracy: 0.3295
# Epoch 256/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0982 - categorical_accuracy: 0.4432
# Epoch 257/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0980 - categorical_accuracy: 0.5114
# Epoch 258/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.0979 - categorical_accuracy: 0.4659
# Epoch 259/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0977 - categorical_accuracy: 0.3977
# Epoch 260/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.0979 - categorical_accuracy: 0.2955
# Epoch 261/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.0976 - categorical_accuracy: 0.2273
# Epoch 262/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0978 - categorical_accuracy: 0.2727
# Epoch 263/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0978 - categorical_accuracy: 0.2841
# Epoch 264/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 1.0982 - categorical_accuracy: 0.3523
# Epoch 265/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0971 - categorical_accuracy: 0.2273
# Epoch 266/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0967 - categorical_accuracy: 0.2727
# Epoch 267/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0966 - categorical_accuracy: 0.4318
# Epoch 268/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0970 - categorical_accuracy: 0.4545
# Epoch 269/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0962 - categorical_accuracy: 0.4432
# Epoch 270/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0961 - categorical_accuracy: 0.3409
# Epoch 271/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0954 - categorical_accuracy: 0.3409
# Epoch 272/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0957 - categorical_accuracy: 0.3636
# Epoch 273/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0952 - categorical_accuracy: 0.3636
# Epoch 274/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0948 - categorical_accuracy: 0.3523
# Epoch 275/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0939 - categorical_accuracy: 0.3977
# Epoch 276/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0937 - categorical_accuracy: 0.3977
# Epoch 277/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0907 - categorical_accuracy: 0.4545
# Epoch 278/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0876 - categorical_accuracy: 0.2500
# Epoch 279/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0845 - categorical_accuracy: 0.2955
# Epoch 280/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0780 - categorical_accuracy: 0.2500
# Epoch 281/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.1063 - categorical_accuracy: 0.2614
# Epoch 282/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0913 - categorical_accuracy: 0.3523
# Epoch 283/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0822 - categorical_accuracy: 0.4659
# Epoch 284/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0832 - categorical_accuracy: 0.3409
# Epoch 285/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0729 - categorical_accuracy: 0.4659
# Epoch 286/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0700 - categorical_accuracy: 0.4205
# Epoch 287/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.6016 - categorical_accuracy: 0.3977
# Epoch 288/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.1008 - categorical_accuracy: 0.3295
# Epoch 289/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.1001 - categorical_accuracy: 0.3295
# Epoch 290/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.1001 - categorical_accuracy: 0.3295
# Epoch 291/2000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 596675 (2.28 MB)
# Trainable params: 596675 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 384ms/step

# %%
actions[np.argmax(res[4])]
# Out:
# 'hello'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'iloveyou'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5')
# Out:
# C:\Users\caioc\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
del model

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[0, 3],
#         [0, 2]],
#
#        [[4, 0],
#         [1, 0]],
#
#        [[3, 0],
#         [2, 0]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.4

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        print(f"Prob {num}: {prob}, Type: {type(prob)}")
        scalar_prob = int(prob * 100) if np.isscalar(prob) else 0
        print(f"Scalar Prob {num}: {scalar_prob}")
        cv2.rectangle(output_frame, (0,60+num*40), (scalar_prob, 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)

    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491232991218567, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# Prob 0: 0.3546566069126129, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349123001098633, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311525821686, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.3546566367149353, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122703075409, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.3546566665172577, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122405052185, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.3546566963195801, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122405052185, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# Prob 0: 0.35465672612190247, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122107028961, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# Prob 0: 0.35465672612190247, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122107028961, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310929775238, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# Prob 0: 0.35465675592422485, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122107028961, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310631752014, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# Prob 0: 0.35465675592422485, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491218090057373, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310631752014, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.35465678572654724, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491218090057373, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310929775238, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# Prob 0: 0.35465678572654724, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491218090057373, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310929775238, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# Prob 0: 0.35465678572654724, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491218090057373, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310929775238, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.35465675592422485, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491215109825134, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310631752014, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# Prob 0: 0.35465675592422485, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491218090057373, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310929775238, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.35465675592422485, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122107028961, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# Prob 0: 0.3546566963195801, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122107028961, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# Prob 0: 0.3546566963195801, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122405052185, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.3546566665172577, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122703075409, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311525821686, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# Prob 0: 0.3546566367149353, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122703075409, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311525821686, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# Prob 0: 0.3546566665172577, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122703075409, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311525821686, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.3546566963195801, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122405052185, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# Prob 0: 0.3546566963195801, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122107028961, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.35465672612190247, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122107028961, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# Prob 0: 0.35465675592422485, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122107028961, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# Prob 0: 0.35465678572654724, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491218090057373, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310929775238, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# Prob 0: 0.35465675592422485, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491218090057373, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310631752014, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# Prob 0: 0.35465672612190247, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122107028961, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# Prob 0: 0.3546566963195801, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122107028961, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# Prob 0: 0.3546566665172577, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122703075409, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311525821686, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.3546566665172577, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122405052185, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# Prob 0: 0.3546566665172577, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122405052185, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.3546566665172577, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122107028961, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310929775238, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# Prob 0: 0.3546566963195801, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122107028961, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# Prob 0: 0.35465672612190247, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122107028961, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310929775238, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# Prob 0: 0.35465678572654724, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491218090057373, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310929775238, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.35465681552886963, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491215109825134, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310631752014, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# hello
# Prob 0: 0.354656845331192, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491212129592896, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310631752014, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# Prob 0: 0.3546568751335144, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491209149360657, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043100357055664, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# Prob 0: 0.3546569347381592, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349120616912842, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043100357055664, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.35465702414512634, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349120318889618, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043100357055664, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# Prob 0: 0.3546570837497711, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.334911972284317, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043097376823425, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.3546571433544159, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491194248199463, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043094396591187, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# Prob 0: 0.3546571731567383, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491191267967224, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043094396591187, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# Prob 0: 0.35465723276138306, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491188287734985, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104309141635895, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.35465723276138306, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491188287734985, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104309141635895, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# Prob 0: 0.35465723276138306, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491185307502747, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104309141635895, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.35465723276138306, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491188287734985, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104309141635895, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.35465720295906067, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491188287734985, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104309141635895, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# Prob 0: 0.3546571433544159, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491191267967224, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104309141635895, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# Prob 0: 0.3546571433544159, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491194248199463, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043097376823425, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.3546570837497711, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.334911972284317, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043097376823425, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.35465699434280396, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349120020866394, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043100357055664, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# Prob 0: 0.3546569347381592, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349120616912842, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310631752014, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# Prob 0: 0.3546569347381592, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349120318889618, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043103337287903, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# Prob 0: 0.35465699434280396, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349120020866394, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043100357055664, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# Prob 0: 0.35465702414512634, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349120020866394, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043100357055664, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# Prob 0: 0.35465705394744873, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.334911972284317, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043097376823425, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# Prob 0: 0.3546570837497711, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.334911972284317, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043097376823425, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# Prob 0: 0.3546570837497711, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.334911972284317, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043097376823425, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.3546570837497711, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.334911972284317, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043097376823425, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.3546570837497711, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.334911972284317, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043097376823425, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# Prob 0: 0.35465705394744873, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.334911972284317, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043094396591187, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# Prob 0: 0.35465705394744873, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349120020866394, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043097376823425, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# Prob 0: 0.35465705394744873, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349120318889618, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043100357055664, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# Prob 0: 0.35465699434280396, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349120318889618, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043100357055664, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.35465696454048157, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349120616912842, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043103337287903, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# Prob 0: 0.3546569347381592, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349120616912842, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043103337287903, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# Prob 0: 0.3546568751335144, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491209149360657, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043100357055664, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# Prob 0: 0.354656845331192, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491212129592896, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310631752014, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# Prob 0: 0.35465681552886963, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491215109825134, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310631752014, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.35465675592422485, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491218090057373, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310631752014, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.35465675592422485, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122107028961, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.35465675592422485, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122107028961, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310929775238, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.35465675592422485, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491218090057373, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310631752014, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.35465678572654724, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491218090057373, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310929775238, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# Prob 0: 0.35465678572654724, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491218090057373, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310929775238, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# Prob 0: 0.35465678572654724, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491218090057373, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310929775238, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.35465678572654724, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491218090057373, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310929775238, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# Prob 0: 0.35465678572654724, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491215109825134, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310929775238, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.35465675592422485, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491215109825134, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104310631752014, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# Prob 0: 0.35465672612190247, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122107028961, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311227798462, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# Prob 0: 0.3546566367149353, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.3349122703075409, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.3104311525821686, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# Prob 0: 0.3546565771102905, Type: <class 'numpy.float32'>
# Scalar Prob 0: 35
# Prob 1: 0.33491235971450806, Type: <class 'numpy.float32'>
# Scalar Prob 1: 33
# Prob 2: 0.31043118238449097, Type: <class 'numpy.float32'>
# Scalar Prob 2: 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 20
#      17 print(results)
#      19 # Draw landmarks
# ---> 20 draw_styled_landmarks(image, results)
#      22 # 2. Prediction logic
#      23 keypoints = extract_keypoints(results)
#
# Cell In[6], line 3, in draw_styled_landmarks(image, results)
#       1 def draw_styled_landmarks(image, results):
#       2     # Draw face connections
# ----> 3     mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
#       4                              mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
#       5                              mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
#       6                              )
#       7     # Draw pose connections
#       8     mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
#       9                              mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
#      10                              mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
#      11                              )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mediapipe\python\solutions\drawing_utils.py:179, in draw_landmarks(image, landmark_list, connections, landmark_drawing_spec, connection_drawing_spec)
#     176     if start_idx in idx_to_coordinates and end_idx in idx_to_coordinates:
#     177       drawing_spec = connection_drawing_spec[connection] if isinstance(
#     178           connection_drawing_spec, Mapping) else connection_drawing_spec
# --> 179       cv2.line(image, idx_to_coordinates[start_idx],
#     180                idx_to_coordinates[end_idx], drawing_spec.color,
#     181                drawing_spec.thickness)
#     182 # Draws landmark points after finishing the connection lines, which is
#     183 # aesthetically better.
#     184 if landmark_drawing_spec:
#
# KeyboardInterrupt:
